# %%
import numpy as np
import matplotlib.pyplot as plt

import torch
import torchvision
import torchsummary
# !pip install torchmetrics
import torchmetrics
# Out:
# Collecting torchmetrics
#   Downloading torchmetrics-0.8.2-py3-none-any.whl (409 kB)
#      |████████████████████████████████| 409 kB 38.3 MB/s
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from torchmetrics) (21.3)
# Requirement already satisfied: torch>=1.3.1 in /usr/local/lib/python3.7/dist-packages (from torchmetrics) (1.11.0+cu113)
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.7/dist-packages (from torchmetrics) (1.21.6)
# Collecting pyDeprecate==0.3.*
#   Downloading pyDeprecate-0.3.2-py3-none-any.whl (10 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.3.1->torchmetrics) (4.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->torchmetrics) (3.0.8)
# Installing collected packages: pyDeprecate, torchmetrics
# Successfully installed pyDeprecate-0.3.2 torchmetrics-0.8.2

# %% [markdown]
# ### Cargamos dataset desde pytorch

# %%
train_set = torchvision.datasets.CIFAR10(root='./data', train=True, download=True)
test_set = torchvision.datasets.CIFAR10(root='./data', train=False, download=True)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
#   0%|          | 0/170498071 [00:00<?, ?it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified

# %%
print("### Descripción del conjunto de entrenamiento ###")
print(train_set)
print("### Dimensiones de un ejemplo del dataset ###")
print(np.shape(train_set[0][0]))
print("### Descripción del conjunto de evaluación ###")
print(test_set)

# Ploteo algunas imagenes del dataset y sus etiquetas
for i in range(9):
    image, label = train_set[i]
    plt.subplot(331 + i)
    plt.imshow(image, cmap=plt.get_cmap('gray'))
    print("Label de la imágen {}: {}".format(i, label))

plt.show()
# Out:
# ### Descripción del conjunto de entrenamiento ###
# Dataset CIFAR10
#     Number of datapoints: 50000
#     Root location: ./data
#     Split: Train
# ### Dimensiones de un ejemplo del dataset ###
# (32, 32, 3)
# ### Descripción del conjunto de evaluación ###
# Dataset CIFAR10
#     Number of datapoints: 10000
#     Root location: ./data
#     Split: Test
# Label de la imágen 0: 6
# Label de la imágen 1: 9
# Label de la imágen 2: 9
# Label de la imágen 3: 4
# Label de la imágen 4: 1
# Label de la imágen 5: 1
# Label de la imágen 6: 2
# Label de la imágen 7: 7
# Label de la imágen 8: 8

# %%
data_transforms = torchvision.transforms.Compose([
                    torchvision.transforms.ToTensor()
                  ])

train_set = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform= data_transforms)
test_set = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform = data_transforms)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
valid_set_size = 5000

train_set, valid_set = torch.utils.data.random_split(train_set, [len(train_set) - valid_set_size, valid_set_size])

print("Tamaño del conjunto de entrenamiento: {}".format(len(train_set)))
print("Tamaño del conjunto de validación: {}".format(len(valid_set)))
# Out:
# Tamaño del conjunto de entrenamiento: 45000
# Tamaño del conjunto de validación: 5000

# %%
train_loader = torch.utils.data.DataLoader(train_set, batch_size=45, shuffle=True)
valid_loader = torch.utils.data.DataLoader(valid_set, batch_size=len(valid_set), shuffle=True)
test_loader = torch.utils.data.DataLoader(test_set, batch_size=len(test_set), shuffle=True)

# %% [markdown]
# ### Creación de la Red Neuronal

# %%
class ConvModel(torch.nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = torch.nn.Conv2d(in_channels=3, out_channels=16, kernel_size=3, stride=1, padding='same')
        self.pool1 = torch.nn.MaxPool2d(kernel_size=2, stride=2)
        self.conv2 = torch.nn.Conv2d(in_channels=16, out_channels=32, kernel_size=3, stride=1, padding='same')
        self.pool2 = torch.nn.MaxPool2d(kernel_size=2, stride=2)
        self.conv3 = torch.nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, stride=1, padding='same')
        self.pool3 = torch.nn.MaxPool2d(kernel_size=2, stride=2)
        self.conv4 = torch.nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, stride=1, padding='same')
        self.pool4 = torch.nn.MaxPool2d(kernel_size=2, stride=2)
        self.fc1 = torch.nn.Linear(in_features=512, out_features=100)
        self.fc2 = torch.nn.Linear(in_features=100, out_features=10)

    def forward(self, x):
        x = self.pool1(torch.relu(self.conv1(x)))
        x = self.pool2(torch.relu(self.conv2(x)))
        x = self.pool3(torch.relu(self.conv3(x)))
        x = self.pool4(torch.relu(self.conv4(x)))
        x = torch.flatten(x, 1)
        x = torch.relu(self.fc1(x))
        x = self.fc2(x)
        return x

conv_model = ConvModel()

if torch.cuda.is_available():
    conv_model.to("cuda")

torchsummary.summary(conv_model, (3, 32, 32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 16, 32, 32]             448
#          MaxPool2d-2           [-1, 16, 16, 16]               0
#             Conv2d-3           [-1, 32, 16, 16]           4,640
#          MaxPool2d-4             [-1, 32, 8, 8]               0
#             Conv2d-5             [-1, 64, 8, 8]          18,496
#          MaxPool2d-6             [-1, 64, 4, 4]               0
#             Conv2d-7            [-1, 128, 4, 4]          73,856
#          MaxPool2d-8            [-1, 128, 2, 2]               0
#             Linear-9                  [-1, 100]          51,300
#            Linear-10                   [-1, 10]           1,010
# ================================================================
# Total params: 149,750
# Trainable params: 149,750
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 0.29
# Params size (MB): 0.57
# Estimated Total Size (MB): 0.88
# ----------------------------------------------------------------

# %% [markdown]
# ### primer entrenamiento con 20 epochs sin data augmentation

# %%
conv_model_optimizer = torch.optim.Adam(conv_model.parameters(), lr=0.001)

conv_model_loss = torch.nn.CrossEntropyLoss()

conv_model_accuracy = torchmetrics.Accuracy()

if torch.cuda.is_available():
    conv_model_accuracy.to("cuda")

epochs = 20

train_loss = []
train_acc = []
valid_loss = []
valid_acc = []


for epoch in range(epochs):

    epoch_train_loss = 0.0
    epoch_train_accuracy = 0.0

    for train_data, train_target in train_loader:
        
        if torch.cuda.is_available():
            train_data = train_data.to("cuda")
            train_target = train_target.to("cuda")

        conv_model_optimizer.zero_grad()
    
        output = conv_model(train_data)
    
        loss = conv_model_loss(output, train_target)
        epoch_train_loss += loss.item()
        loss.backward()
    
        conv_model_optimizer.step()

        accuracy = conv_model_accuracy(output, train_target)
        epoch_train_accuracy += accuracy.item()

  
    epoch_train_loss = epoch_train_loss / len(train_loader)
    epoch_train_accuracy = epoch_train_accuracy / len(train_loader)
    train_loss.append(epoch_train_loss)
    train_acc.append(epoch_train_accuracy)

 
    epoch_valid_loss = 0.0
    epoch_valid_accuracy = 0.0

    for valid_data, valid_target in valid_loader:
        if torch.cuda.is_available():
            valid_data = valid_data.to("cuda")
            valid_target = valid_target.to("cuda")
 
        output = conv_model(valid_data)
        epoch_valid_loss += conv_model_loss(output, valid_target).item()
        epoch_valid_accuracy += conv_model_accuracy(output, valid_target).item()
      
    epoch_valid_loss = epoch_valid_loss / len(valid_loader)
    epoch_valid_accuracy = epoch_valid_accuracy / len(valid_loader)
    valid_loss.append(epoch_valid_loss)
    valid_acc.append(epoch_valid_accuracy)

    print("Epoch: {}/{} - Train loss {:.6f} - Train Accuracy {:.6f} - Valid Loss {:.6f} - Valid Accuracy {:.6f}".format(
      epoch+1, epochs, epoch_train_loss, epoch_train_accuracy, epoch_valid_loss, epoch_valid_accuracy))
# Out:
# Epoch: 1/20 - Train loss 1.657599 - Train Accuracy 0.383644 - Valid Loss 1.368512 - Valid Accuracy 0.493600
# Epoch: 2/20 - Train loss 1.295524 - Train Accuracy 0.531756 - Valid Loss 1.187500 - Valid Accuracy 0.572400
# Epoch: 3/20 - Train loss 1.119720 - Train Accuracy 0.599067 - Valid Loss 1.094342 - Valid Accuracy 0.604200
# Epoch: 4/20 - Train loss 0.988308 - Train Accuracy 0.645400 - Valid Loss 0.998701 - Valid Accuracy 0.648800
# Epoch: 5/20 - Train loss 0.892729 - Train Accuracy 0.684289 - Valid Loss 0.991209 - Valid Accuracy 0.658200
# Epoch: 6/20 - Train loss 0.811093 - Train Accuracy 0.713822 - Valid Loss 0.906961 - Valid Accuracy 0.689800
# Epoch: 7/20 - Train loss 0.736924 - Train Accuracy 0.740778 - Valid Loss 0.849062 - Valid Accuracy 0.705000
# Epoch: 8/20 - Train loss 0.678654 - Train Accuracy 0.760400 - Valid Loss 0.844370 - Valid Accuracy 0.710000
# Epoch: 9/20 - Train loss 0.621748 - Train Accuracy 0.781533 - Valid Loss 0.843169 - Valid Accuracy 0.717200
# Epoch: 10/20 - Train loss 0.572250 - Train Accuracy 0.796644 - Valid Loss 0.901238 - Valid Accuracy 0.703400
# Epoch: 11/20 - Train loss 0.535069 - Train Accuracy 0.811933 - Valid Loss 0.894181 - Valid Accuracy 0.708800
# Epoch: 12/20 - Train loss 0.486892 - Train Accuracy 0.825778 - Valid Loss 0.905472 - Valid Accuracy 0.714600
# Epoch: 13/20 - Train loss 0.443344 - Train Accuracy 0.841422 - Valid Loss 0.920836 - Valid Accuracy 0.711000
# Epoch: 14/20 - Train loss 0.404919 - Train Accuracy 0.855511 - Valid Loss 0.988780 - Valid Accuracy 0.699200
# Epoch: 15/20 - Train loss 0.376900 - Train Accuracy 0.865200 - Valid Loss 1.026399 - Valid Accuracy 0.716600
# Epoch: 16/20 - Train loss 0.338513 - Train Accuracy 0.878356 - Valid Loss 1.051563 - Valid Accuracy 0.712200
# Epoch: 17/20 - Train loss 0.306377 - Train Accuracy 0.889667 - Valid Loss 1.138295 - Valid Accuracy 0.711000
# Epoch: 18/20 - Train loss 0.284963 - Train Accuracy 0.895822 - Valid Loss 1.176801 - Valid Accuracy 0.706800
# Epoch: 19/20 - Train loss 0.264350 - Train Accuracy 0.904089 - Valid Loss 1.258167 - Valid Accuracy 0.690000
# Epoch: 20/20 - Train loss 0.246132 - Train Accuracy 0.911933 - Valid Loss 1.262175 - Valid Accuracy 0.708600

# %%
fig, axs = plt.subplots(2, 1, figsize=(15,15))

axs[0].plot(train_loss[1:]) 
axs[0].plot(valid_loss[1:]) 
axs[0].title.set_text('Error de Entrenamiento vs Validación') 
axs[0].legend(['Train', 'Valid'])  

axs[1].plot(train_acc) 
axs[1].plot(valid_acc) 
axs[1].title.set_text('Accuracy de Entrenamiento vs Validación') 
axs[1].legend(['Train', 'Valid'])

# %%
test_loss = 0.0
test_accuracy = 0.0

for test_data, test_target in test_loader:
    if torch.cuda.is_available():
        test_data, test_target = test_data.cuda(), test_target.cuda()
        
    output = conv_model(test_data)
    test_loss += conv_model_loss(output, test_target).item()
    test_accuracy += conv_model_accuracy(output, test_target).item()

test_loss = test_loss / len(test_loader)
test_accuracy = test_accuracy / len(test_loader)

print("El modelo logro un error de {:.6f} y una accuracy de {:.6f}".format(test_loss, test_accuracy))
# Out:
# El modelo logro un error de 1.368769 y una accuracy de 0.693500

# %% [markdown]
# Vemos que se produce sobre entrenamiento porque el modelo tiene buenas métricas sobre el dataset de training pero no sobre el dataset de validación y Testing. Esto se debe a que el dataset puede ser muy pequeño.

# %% [markdown]
# ### Entrenamiento con data augmentation

# %%
aug_data_transforms = torchvision.transforms.Compose([
                        torchvision.transforms.RandomHorizontalFlip(0.5),
                        #torchvision.transforms.RandomResizedCrop(size=(32, 32), scale=(0.5, 1.0)),
                        #torchvision.transforms.ColorJitter(saturation=0.05, hue=0.05),
                        #torchvision.transforms.CenterCrop(size=(32,32)),
                        torchvision.transforms.ToTensor(),
                      ])

aug_train_set = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform= aug_data_transforms)
# Out:
# Files already downloaded and verified

# %%
fig, rows = plt.subplots(nrows=1, ncols=4, figsize=(18, 18))

for id, row in enumerate(rows):
    row.imshow(aug_train_set[id][0].permute(1, 2, 0))
    row.axis('off')
plt.show()

# %%
aug_valid_set_size = 5000

aug_train_set, aug_valid_set = torch.utils.data.random_split(aug_train_set, [len(aug_train_set) - aug_valid_set_size, aug_valid_set_size])

print("Tamaño del conjunto de entrenamiento: {}".format(len(aug_train_set)))
print("Tamaño del conjunto de validación: {}".format(len(aug_valid_set)))
# Out:
# Tamaño del conjunto de entrenamiento: 45000
# Tamaño del conjunto de validación: 5000

# %%
aug_train_loader = torch.utils.data.DataLoader(aug_train_set, batch_size=45, shuffle=True)
aug_valid_loader = torch.utils.data.DataLoader(aug_valid_set, batch_size=len(valid_set), shuffle=True)

# %%
aug_conv_model = ConvModel()

if torch.cuda.is_available():
    aug_conv_model = aug_conv_model.to("cuda")

aug_conv_model_optimizer = torch.optim.Adam(aug_conv_model.parameters(), lr=0.0001)

aug_conv_model_loss = torch.nn.CrossEntropyLoss()

aug_conv_model_accuracy = torchmetrics.Accuracy()

if torch.cuda.is_available():
    aug_conv_model_accuracy = aug_conv_model_accuracy.to("cuda")

epochs = 60

train_loss = []
train_acc = []
valid_loss = []
valid_acc = []


for epoch in range(epochs):
    
    epoch_train_loss = 0.0
    epoch_train_accuracy = 0.0
    
    for aug_train_data, aug_train_target in aug_train_loader:
        
        if torch.cuda.is_available():
            aug_train_data = aug_train_data.to("cuda")
            aug_train_target = aug_train_target.to("cuda")

        aug_conv_model_optimizer.zero_grad()
    
        aug_output = aug_conv_model(aug_train_data)
    
        aug_loss = aug_conv_model_loss(aug_output, aug_train_target)
        epoch_train_loss += aug_loss.item()
        aug_loss.backward()
    
        aug_conv_model_optimizer.step()
        accuracy = aug_conv_model_accuracy(aug_output, aug_train_target)
        epoch_train_accuracy += accuracy.item()


    epoch_train_loss = epoch_train_loss / len(aug_train_loader)
    epoch_train_accuracy = epoch_train_accuracy / len(aug_train_loader)
    train_loss.append(epoch_train_loss)
    train_acc.append(epoch_train_accuracy)

    epoch_valid_loss = 0.0
    epoch_valid_accuracy = 0.0

    for aug_valid_data, aug_valid_target in aug_valid_loader:
        if torch.cuda.is_available():
            aug_valid_data = aug_valid_data.to("cuda")
            aug_valid_target = aug_valid_target.to("cuda")

        aug_output = aug_conv_model(aug_valid_data)
        epoch_valid_loss += aug_conv_model_loss(aug_output, aug_valid_target).item()
        epoch_valid_accuracy += aug_conv_model_accuracy(aug_output, aug_valid_target).item()
      
    epoch_valid_loss = epoch_valid_loss / len(aug_valid_loader)
    epoch_valid_accuracy = epoch_valid_accuracy / len(aug_valid_loader)
    valid_loss.append(epoch_valid_loss)
    valid_acc.append(epoch_valid_accuracy)

    print("Epoch: {}/{} - Train loss {:.6f} - Train Accuracy {:.6f} - Valid Loss {:.6f} - Valid Accuracy {:.6f}".format(
      epoch+1, epochs, epoch_train_loss, epoch_train_accuracy, epoch_valid_loss, epoch_valid_accuracy))
# Out:
# Epoch: 1/60 - Train loss 1.988935 - Train Accuracy 0.261089 - Valid Loss 1.787810 - Valid Accuracy 0.349800
# Epoch: 2/60 - Train loss 1.712216 - Train Accuracy 0.379133 - Valid Loss 1.619664 - Valid Accuracy 0.420200
# Epoch: 3/60 - Train loss 1.598110 - Train Accuracy 0.418400 - Valid Loss 1.545501 - Valid Accuracy 0.444200
# Epoch: 4/60 - Train loss 1.525736 - Train Accuracy 0.446711 - Valid Loss 1.477995 - Valid Accuracy 0.469000
# Epoch: 5/60 - Train loss 1.472556 - Train Accuracy 0.464200 - Valid Loss 1.421294 - Valid Accuracy 0.492400
# Epoch: 6/60 - Train loss 1.426266 - Train Accuracy 0.482689 - Valid Loss 1.383538 - Valid Accuracy 0.507200
# Epoch: 7/60 - Train loss 1.387922 - Train Accuracy 0.499111 - Valid Loss 1.370998 - Valid Accuracy 0.508600
# Epoch: 8/60 - Train loss 1.357019 - Train Accuracy 0.512022 - Valid Loss 1.361899 - Valid Accuracy 0.515200
# Epoch: 9/60 - Train loss 1.328233 - Train Accuracy 0.520600 - Valid Loss 1.312520 - Valid Accuracy 0.530600
# Epoch: 10/60 - Train loss 1.301472 - Train Accuracy 0.535644 - Valid Loss 1.267549 - Valid Accuracy 0.556200
# Epoch: 11/60 - Train loss 1.279704 - Train Accuracy 0.540556 - Valid Loss 1.280569 - Valid Accuracy 0.545000
# Epoch: 12/60 - Train loss 1.253010 - Train Accuracy 0.550822 - Valid Loss 1.237798 - Valid Accuracy 0.564400
# Epoch: 13/60 - Train loss 1.236049 - Train Accuracy 0.558556 - Valid Loss 1.255238 - Valid Accuracy 0.562000
# Epoch: 14/60 - Train loss 1.212215 - Train Accuracy 0.567778 - Valid Loss 1.200207 - Valid Accuracy 0.564400
# Epoch: 15/60 - Train loss 1.190827 - Train Accuracy 0.576800 - Valid Loss 1.190669 - Valid Accuracy 0.582000
# Epoch: 16/60 - Train loss 1.169908 - Train Accuracy 0.585489 - Valid Loss 1.182836 - Valid Accuracy 0.575800
# Epoch: 17/60 - Train loss 1.146346 - Train Accuracy 0.593444 - Valid Loss 1.146606 - Valid Accuracy 0.591000
# Epoch: 18/60 - Train loss 1.130443 - Train Accuracy 0.600844 - Valid Loss 1.128258 - Valid Accuracy 0.593800
# Epoch: 19/60 - Train loss 1.110997 - Train Accuracy 0.608822 - Valid Loss 1.156963 - Valid Accuracy 0.584400
# Epoch: 20/60 - Train loss 1.093401 - Train Accuracy 0.613400 - Valid Loss 1.098018 - Valid Accuracy 0.610400
# Epoch: 21/60 - Train loss 1.074274 - Train Accuracy 0.620533 - Valid Loss 1.086471 - Valid Accuracy 0.618600
# Epoch: 22/60 - Train loss 1.054301 - Train Accuracy 0.627956 - Valid Loss 1.063171 - Valid Accuracy 0.632000
# Epoch: 23/60 - Train loss 1.037380 - Train Accuracy 0.633667 - Valid Loss 1.065431 - Valid Accuracy 0.622000
# Epoch: 24/60 - Train loss 1.022494 - Train Accuracy 0.641467 - Valid Loss 1.070248 - Valid Accuracy 0.622200
# Epoch: 25/60 - Train loss 1.005403 - Train Accuracy 0.647778 - Valid Loss 1.017966 - Valid Accuracy 0.644200
# Epoch: 26/60 - Train loss 0.989866 - Train Accuracy 0.652822 - Valid Loss 1.007322 - Valid Accuracy 0.648800
# Epoch: 27/60 - Train loss 0.976855 - Train Accuracy 0.659244 - Valid Loss 1.003478 - Valid Accuracy 0.651400
# Epoch: 28/60 - Train loss 0.961672 - Train Accuracy 0.663756 - Valid Loss 1.019443 - Valid Accuracy 0.649400
# Epoch: 29/60 - Train loss 0.949223 - Train Accuracy 0.669978 - Valid Loss 0.994804 - Valid Accuracy 0.649000
# Epoch: 30/60 - Train loss 0.934803 - Train Accuracy 0.672822 - Valid Loss 1.021483 - Valid Accuracy 0.650000
# Epoch: 31/60 - Train loss 0.923555 - Train Accuracy 0.677978 - Valid Loss 0.957302 - Valid Accuracy 0.663000
# Epoch: 32/60 - Train loss 0.910936 - Train Accuracy 0.682156 - Valid Loss 0.949764 - Valid Accuracy 0.670800
# Epoch: 33/60 - Train loss 0.896265 - Train Accuracy 0.688533 - Valid Loss 0.990298 - Valid Accuracy 0.645200
# Epoch: 34/60 - Train loss 0.888136 - Train Accuracy 0.688356 - Valid Loss 0.937602 - Valid Accuracy 0.669200
# Epoch: 35/60 - Train loss 0.879230 - Train Accuracy 0.693267 - Valid Loss 0.938704 - Valid Accuracy 0.674400
# Epoch: 36/60 - Train loss 0.869617 - Train Accuracy 0.697133 - Valid Loss 0.932796 - Valid Accuracy 0.679000
# Epoch: 37/60 - Train loss 0.857010 - Train Accuracy 0.703489 - Valid Loss 0.917214 - Valid Accuracy 0.677000
# Epoch: 38/60 - Train loss 0.848653 - Train Accuracy 0.702378 - Valid Loss 0.904012 - Valid Accuracy 0.684400
# Epoch: 39/60 - Train loss 0.836764 - Train Accuracy 0.708644 - Valid Loss 0.922015 - Valid Accuracy 0.680600
# Epoch: 40/60 - Train loss 0.826606 - Train Accuracy 0.711867 - Valid Loss 0.887498 - Valid Accuracy 0.687000
# Epoch: 41/60 - Train loss 0.816159 - Train Accuracy 0.715644 - Valid Loss 0.910716 - Valid Accuracy 0.684200
# Epoch: 42/60 - Train loss 0.807200 - Train Accuracy 0.717556 - Valid Loss 0.866306 - Valid Accuracy 0.692800
# Epoch: 43/60 - Train loss 0.798444 - Train Accuracy 0.723733 - Valid Loss 0.864023 - Valid Accuracy 0.699600
# Epoch: 44/60 - Train loss 0.792252 - Train Accuracy 0.724956 - Valid Loss 0.882309 - Valid Accuracy 0.696000
# Epoch: 45/60 - Train loss 0.784498 - Train Accuracy 0.726489 - Valid Loss 0.869368 - Valid Accuracy 0.696400
# Epoch: 46/60 - Train loss 0.775129 - Train Accuracy 0.729689 - Valid Loss 0.881250 - Valid Accuracy 0.693800
# Epoch: 47/60 - Train loss 0.765894 - Train Accuracy 0.733933 - Valid Loss 0.860126 - Valid Accuracy 0.701400
# Epoch: 48/60 - Train loss 0.758960 - Train Accuracy 0.734844 - Valid Loss 0.874705 - Valid Accuracy 0.696400
# Epoch: 49/60 - Train loss 0.754119 - Train Accuracy 0.737333 - Valid Loss 0.841056 - Valid Accuracy 0.705800
# Epoch: 50/60 - Train loss 0.743440 - Train Accuracy 0.741000 - Valid Loss 0.837674 - Valid Accuracy 0.708200
# Epoch: 51/60 - Train loss 0.737657 - Train Accuracy 0.742356 - Valid Loss 0.824089 - Valid Accuracy 0.710800
# Epoch: 52/60 - Train loss 0.724901 - Train Accuracy 0.747956 - Valid Loss 0.853496 - Valid Accuracy 0.708200
# Epoch: 53/60 - Train loss 0.722822 - Train Accuracy 0.750400 - Valid Loss 0.838782 - Valid Accuracy 0.707600
# Epoch: 54/60 - Train loss 0.715422 - Train Accuracy 0.751400 - Valid Loss 0.859294 - Valid Accuracy 0.700600
# Epoch: 55/60 - Train loss 0.706605 - Train Accuracy 0.754378 - Valid Loss 0.819354 - Valid Accuracy 0.714600
# Epoch: 56/60 - Train loss 0.700258 - Train Accuracy 0.756244 - Valid Loss 0.835362 - Valid Accuracy 0.706200
# Epoch: 57/60 - Train loss 0.692731 - Train Accuracy 0.757289 - Valid Loss 0.847294 - Valid Accuracy 0.704800
# Epoch: 58/60 - Train loss 0.686266 - Train Accuracy 0.761556 - Valid Loss 0.820979 - Valid Accuracy 0.712600
# Epoch: 59/60 - Train loss 0.680035 - Train Accuracy 0.762956 - Valid Loss 0.786879 - Valid Accuracy 0.722800
# Epoch: 60/60 - Train loss 0.670227 - Train Accuracy 0.764956 - Valid Loss 0.810329 - Valid Accuracy 0.719600

# %%
fig, axs = plt.subplots(2, 1, figsize=(15,15))

axs[0].plot(train_loss[1:]) 
axs[0].plot(valid_loss[1:]) 
axs[0].title.set_text('Error de Entrenamiento vs Validación') 
axs[0].legend(['Train', 'Valid'])  

axs[1].plot(train_acc) 
axs[1].plot(valid_acc) 
axs[1].title.set_text('Accuracy de Entrenamiento vs Validación') 
axs[1].legend(['Train', 'Valid'])

# %%
test_loss = 0.0
test_accuracy = 0.0

for test_data, test_target in test_loader:
    
    if torch.cuda.is_available():
        test_data, test_target = test_data.cuda(), test_target.cuda()
    output = aug_conv_model(test_data)
    test_loss += aug_conv_model_loss(output, test_target).item()
    test_accuracy += aug_conv_model_accuracy(output, test_target).item()

test_loss = test_loss / len(test_loader)
test_accuracy = test_accuracy / len(test_loader)

print("El modelo logro un error de {:.6f} y una accuracy de {:.6f}".format(test_loss, test_accuracy))
# Out:
# El modelo logro un error de 0.821879 y una accuracy de 0.720000

# %% [markdown]
# La razón por la cual el entrenamiento es más lento es porque el dataset en cada época es diferente debido a las transformaciones aleatorias que estamos aplicando: es como si el dataset fuera el doble en este caso que sólo apliqué una transformación. Cuando probé con dos o tres transformaciones, el entrenamiento era mucho más lento y sobre la época 50 intentaba irse al overffiting, por esta razón decidí dejar sólo una transformación.
